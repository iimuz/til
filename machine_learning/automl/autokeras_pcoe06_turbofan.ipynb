# %% [markdown]
# # Autokeras
#
# [PCoE][pcoe]の No.6 Turbofan Engine Degradation Simulation Dataset に対して [Autokeras][autokeras] を利用したAutoMLの実行テスト。
#
# [autokeras]: https://autokeras.com/
# [pcoe]: https://ti.arc.nasa.gov/tech/dash/groups/pcoe/prognostic-data-repository/

# %% [markdown]
# # Install Autokeras

# %%
try:
    import autokeras as ak
except ModuleNotFoundError:
    # https://autokeras.com/install/
    # !pip install git+https://github.com/keras-team/keras-tuner.git
    # !pip install autokeras


import autokeras as ak
from autokeras import StructuredDataRegressor
# Out:
# Collecting git+https://github.com/keras-team/keras-tuner.git
#   Cloning https://github.com/keras-team/keras-tuner.git to /tmp/pip-req-build-6vm6824c
#   Running command git clone -q https://github.com/keras-team/keras-tuner.git /tmp/pip-req-build-6vm6824c
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras-tuner==1.0.3) (20.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-tuner==1.0.3) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras-tuner==1.0.3) (2.23.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from keras-tuner==1.0.3) (1.4.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras-tuner==1.0.3) (2.4.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras-tuner==1.0.3) (5.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras-tuner==1.0.3) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner==1.0.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner==1.0.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner==1.0.3) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner==1.0.3) (2.10)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (3.12.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (1.8.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (0.36.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (0.12.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (56.1.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (1.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (0.4.4)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (1.32.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (3.3.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner==1.0.3) (1.15.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner==1.0.3) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner==1.0.3) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner==1.0.3) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner==1.0.3) (0.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner==1.0.3) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner==1.0.3) (5.0.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner==1.0.3) (4.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard->keras-tuner==1.0.3) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard->keras-tuner==1.0.3) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard->keras-tuner==1.0.3) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner==1.0.3) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras-tuner==1.0.3) (3.10.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras-tuner==1.0.3) (0.2.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.2->ipython->keras-tuner==1.0.3) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython->keras-tuner==1.0.3) (0.7.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard->keras-tuner==1.0.3) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner==1.0.3) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->keras-tuner==1.0.3) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->keras-tuner==1.0.3) (3.7.4.3)
# Building wheels for collected packages: keras-tuner
#   Building wheel for keras-tuner (setup.py) ... done
#   Created wheel for keras-tuner: filename=keras_tuner-1.0.3-cp37-none-any.whl size=93799 sha256=029583ef4d0f6b43b42ceee0833fd202bf7e392ad108b29d913d05e20a753936
#   Stored in directory: /tmp/pip-ephem-wheel-cache-847sskb3/wheels/33/f9/be/250538026c0381bfee3fe34b533f483c15dbfde8fbb61c8bbd
# Successfully built keras-tuner
# Installing collected packages: keras-tuner
# Successfully installed keras-tuner-1.0.3
# Collecting autokeras
#   Downloading https://files.pythonhosted.org/packages/09/12/cf698586ccc8245f08d1843dcafb65b064a2e9e2923b889dc58e1019f099/autokeras-1.0.12-py3-none-any.whl (164kB)
#      |████████████████████████████████| 174kB 18.6MB/s
# Requirement already satisfied: tensorflow>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from autokeras) (2.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from autokeras) (1.1.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from autokeras) (20.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from autokeras) (0.22.2.post1)
# Requirement already satisfied: keras-tuner>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from autokeras) (1.0.3)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (2.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (1.1.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (3.7.4.3)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (2.10.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (3.12.4)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (1.1.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (1.15.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (2.4.1)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (0.2.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (1.19.5)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (1.32.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (3.3.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (0.12.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (1.6.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (0.36.2)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->autokeras) (1.12.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->autokeras) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->autokeras) (2.8.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->autokeras) (2.4.7)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->autokeras) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->autokeras) (1.0.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras-tuner>=1.0.2->autokeras) (5.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras-tuner>=1.0.2->autokeras) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.9.2->tensorflow>=2.3.0->autokeras) (56.1.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (1.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (3.3.4)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.0.2->autokeras) (5.0.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.0.2->autokeras) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.0.2->autokeras) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.0.2->autokeras) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.0.2->autokeras) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.0.2->autokeras) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.0.2->autokeras) (1.0.18)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner>=1.0.2->autokeras) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner>=1.0.2->autokeras) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner>=1.0.2->autokeras) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner>=1.0.2->autokeras) (1.24.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (3.10.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.2->ipython->keras-tuner>=1.0.2->autokeras) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython->keras-tuner>=1.0.2->autokeras) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras-tuner>=1.0.2->autokeras) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (3.4.1)
# Installing collected packages: autokeras
# Successfully installed autokeras-1.0.12

# %% [markdown]
# # Preset

# %%
# default packages
import logging
import pathlib
import zipfile
from typing import Any, Dict, List, Sequence, Tuple

# %%
# third party packages
import IPython.display as display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import seaborn as sns
import sklearn.model_selection as skmselection
import tensorflow.keras.models as tkmodels
import tensorflow.keras.callbacks as tkcallbacks
import tqdm.autonotebook as tqdm
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   # This is added back by InteractiveShellApp.init_path()

# %%
# mode
MODE_DEBUG = False

# %%
# logger
_logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.DEBUG if MODE_DEBUG else logging.INFO)

# %%
# seaborn
sns.set()

# %% [markdown]
# # Global parameters

# %%
PATH_ARCHIVE = pathlib.Path("turbofun.zip")
PATH_EXTRACT = pathlib.Path("turbofun")

# %%
# 利用する変数を定義
COLUMNS_ALL = [
    *[f"op{i:02}" for i in range(3)],
    *[f"sensor{i:02}" for i in range(26)],
]
COLUMNS_INVALID = [
    "op02",
    "sensor01",
    "sensor04",
    "sensor09",
    "sensor15",
    "sensor17",
    "sensor18",
    "sensor21",
    "sensor22",
    "sensor23",
    "sensor24",
    "sensor25",
]
COLUMNS_VALID = sorted(list(set(COLUMNS_ALL) - set(COLUMNS_INVALID)))

COLUMNS_TARGET = ["rul"]

# %% [markdown]
# # Load dataset

# %%
def download(filename: pathlib.Path) -> None:
    """zipファイルをダウンロード."""
    if filename.exists():
        return

    url = "https://ti.arc.nasa.gov/c/6/"
    res = requests.get(url, stream=True)
    if res.status_code != 200:
        _logger.error(res.status_code)
        return

    with open(filename, "wb") as f:
        for chunk in tqdm.tqdm(res):
            f.write(chunk)


download(PATH_ARCHIVE)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
def extractall(src: pathlib.Path, dst: pathlib.Path) -> None:
    """zipファイルを解凍."""
    if not src.exists():
        _logger.error(f"{src} does not exist.")
        return
    if dst.exists():
        _logger.error(f"{dst} exists.")
        return

    with zipfile.ZipFile(src) as zf:
        zf.extractall(dst)


extractall(PATH_ARCHIVE, PATH_EXTRACT)

# %% [markdown]
# # Convert data shape

# %%
def get_unit_series(df: pd.DataFrame, unit: int) -> Dict[str, Any]:
    """unit単位のnumpy.arrayへ変換する."""
    df_unit = df[df["unit"] == unit].copy()
    df_unit.sort_values(by=["time"], ignore_index=True, inplace=True)
    names_op = [f"op{i:02}" for i in range(3)]
    names_sensor = [f"sensor{i:02}" for i in range(26)]
    data = {
        "unit": unit,
        **{name: df_unit[name].to_numpy().ravel() for name in names_op},
        **{name: df_unit[name].to_numpy().ravel() for name in names_sensor},
    }

    return data


def load_data(filename: pathlib.Path) -> pd.DataFrame:
    """データを読み取り、1セルに1unit分のデータをnumpy.arrayで保持するDataFrameとする."""
    df = pd.read_csv(
        filename,
        header=None,
        sep=" ",
        names=[
            "unit",
            "time",
            *[f"op{i:02d}" for i in range(3)],
            *[f"sensor{i:02d}" for i in range(26)],
        ],
    )

    return df


DF_FD001_TRAIN = load_data(PATH_EXTRACT.joinpath("train_FD001.txt"))
DF_FD001_TEST = load_data(PATH_EXTRACT.joinpath("test_FD001.txt"))

# %%
display.display(DF_FD001_TRAIN)
# Out:
#        unit  time    op00    op01  ...  sensor22  sensor23  sensor24  sensor25
# 0         1     1 -0.0007 -0.0004  ...       NaN       NaN       NaN       NaN
# 1         1     2  0.0019 -0.0003  ...       NaN       NaN       NaN       NaN
# 2         1     3 -0.0043  0.0003  ...       NaN       NaN       NaN       NaN
# 3         1     4  0.0007  0.0000  ...       NaN       NaN       NaN       NaN
# 4         1     5 -0.0019 -0.0002  ...       NaN       NaN       NaN       NaN
# ...     ...   ...     ...     ...  ...       ...       ...       ...       ...
# 20626   100   196 -0.0004 -0.0003  ...       NaN       NaN       NaN       NaN
# 20627   100   197 -0.0016 -0.0005  ...       NaN       NaN       NaN       NaN
# 20628   100   198  0.0004  0.0000  ...       NaN       NaN       NaN       NaN
# 20629   100   199 -0.0011  0.0003  ...       NaN       NaN       NaN       NaN
# 20630   100   200 -0.0032 -0.0005  ...       NaN       NaN       NaN       NaN
#
# [20631 rows x 31 columns]

# %%
display.display(DF_FD001_TEST)
# Out:
#        unit  time    op00    op01  ...  sensor22  sensor23  sensor24  sensor25
# 0         1     1  0.0023  0.0003  ...       NaN       NaN       NaN       NaN
# 1         1     2 -0.0027 -0.0003  ...       NaN       NaN       NaN       NaN
# 2         1     3  0.0003  0.0001  ...       NaN       NaN       NaN       NaN
# 3         1     4  0.0042  0.0000  ...       NaN       NaN       NaN       NaN
# 4         1     5  0.0014  0.0000  ...       NaN       NaN       NaN       NaN
# ...     ...   ...     ...     ...  ...       ...       ...       ...       ...
# 13091   100   194  0.0049  0.0000  ...       NaN       NaN       NaN       NaN
# 13092   100   195 -0.0011 -0.0001  ...       NaN       NaN       NaN       NaN
# 13093   100   196 -0.0006 -0.0003  ...       NaN       NaN       NaN       NaN
# 13094   100   197 -0.0038  0.0001  ...       NaN       NaN       NaN       NaN
# 13095   100   198  0.0013  0.0003  ...       NaN       NaN       NaN       NaN
#
# [13096 rows x 31 columns]

# %%
def load_rul(filepath: pathlib.Path) -> pd.DataFrame:
    """テスト用のRULを読み込む."""
    df = pd.read_csv(
        filepath,
        header=None,
        sep=" ",
        names=["rul", "none"],
    )
    df.drop(["none"], axis=1, inplace=True)
    df["unit"] = range(len(df))
    df.set_index(["unit"], inplace=True)

    return df


DF_FD001_TEST_RUL = load_rul(PATH_EXTRACT.joinpath("RUL_FD001.txt"))
display.display(DF_FD001_TEST_RUL)
# Out:
#       rul
# unit
# 0     112
# 1      98
# 2      69
# 3      82
# 4      91
# ...   ...
# 95    137
# 96     82
# 97     59
# 98    117
# 99     20
#
# [100 rows x 1 columns]

# %%
def create_train_rul(df: pd.DataFrame) -> pd.Series:
    """学習データに対するRULを算出する."""
    df_rul = df.copy()
    df_max_time = df.groupby(["unit"])["time"].max()
    df_rul["rul"] = df_rul.apply(
        lambda x: df_max_time.at[x["unit"]] - x["time"],
        axis=1,
    )

    return df_rul



DF_FD001_TRAIN = create_train_rul(DF_FD001_TRAIN)
display.display(DF_FD001_TRAIN)
# Out:
#        unit  time    op00    op01  ...  sensor23  sensor24  sensor25    rul
# 0         1     1 -0.0007 -0.0004  ...       NaN       NaN       NaN  191.0
# 1         1     2  0.0019 -0.0003  ...       NaN       NaN       NaN  190.0
# 2         1     3 -0.0043  0.0003  ...       NaN       NaN       NaN  189.0
# 3         1     4  0.0007  0.0000  ...       NaN       NaN       NaN  188.0
# 4         1     5 -0.0019 -0.0002  ...       NaN       NaN       NaN  187.0
# ...     ...   ...     ...     ...  ...       ...       ...       ...    ...
# 20626   100   196 -0.0004 -0.0003  ...       NaN       NaN       NaN    4.0
# 20627   100   197 -0.0016 -0.0005  ...       NaN       NaN       NaN    3.0
# 20628   100   198  0.0004  0.0000  ...       NaN       NaN       NaN    2.0
# 20629   100   199 -0.0011  0.0003  ...       NaN       NaN       NaN    1.0
# 20630   100   200 -0.0032 -0.0005  ...       NaN       NaN       NaN    0.0
#
# [20631 rows x 32 columns]

# %% [markdown]
# # Data split

# %%
def train_test_split(df: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """学習用データと検証用データを分割する."""
    units = df["unit"].unique()
    units_train, units_test = skmselection.train_test_split(
        units,
        test_size=0.2,
        random_state=42,
    )

    df_train = df[df["unit"].isin(units_train)]
    df_test = df[df["unit"].isin(units_test)]

    return df_train, df_test


DF_TRAIN, DF_VALID = train_test_split(DF_FD001_TRAIN)

# %%
DF_TRAIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16561 entries, 192 to 20630
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   unit      16561 non-null  int64
#  1   time      16561 non-null  int64
#  2   op00      16561 non-null  float64
#  3   op01      16561 non-null  float64
#  4   op02      16561 non-null  float64
#  5   sensor00  16561 non-null  float64
#  6   sensor01  16561 non-null  float64
#  7   sensor02  16561 non-null  float64
#  8   sensor03  16561 non-null  float64
#  9   sensor04  16561 non-null  float64
#  10  sensor05  16561 non-null  float64
#  11  sensor06  16561 non-null  float64
#  12  sensor07  16561 non-null  float64
#  13  sensor08  16561 non-null  float64
#  14  sensor09  16561 non-null  float64
#  15  sensor10  16561 non-null  float64
#  16  sensor11  16561 non-null  float64
#  17  sensor12  16561 non-null  float64
#  18  sensor13  16561 non-null  float64
#  19  sensor14  16561 non-null  float64
#  20  sensor15  16561 non-null  float64
#  21  sensor16  16561 non-null  int64
#  22  sensor17  16561 non-null  int64
#  23  sensor18  16561 non-null  float64
#  24  sensor19  16561 non-null  float64
#  25  sensor20  16561 non-null  float64
#  26  sensor21  0 non-null      float64
#  27  sensor22  0 non-null      float64
#  28  sensor23  0 non-null      float64
#  29  sensor24  0 non-null      float64
#  30  sensor25  0 non-null      float64
#  31  rul       16561 non-null  float64
# dtypes: float64(28), int64(4)
# memory usage: 4.2 MB

# %%
DF_VALID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4070 entries, 0 to 18514
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   unit      4070 non-null   int64
#  1   time      4070 non-null   int64
#  2   op00      4070 non-null   float64
#  3   op01      4070 non-null   float64
#  4   op02      4070 non-null   float64
#  5   sensor00  4070 non-null   float64
#  6   sensor01  4070 non-null   float64
#  7   sensor02  4070 non-null   float64
#  8   sensor03  4070 non-null   float64
#  9   sensor04  4070 non-null   float64
#  10  sensor05  4070 non-null   float64
#  11  sensor06  4070 non-null   float64
#  12  sensor07  4070 non-null   float64
#  13  sensor08  4070 non-null   float64
#  14  sensor09  4070 non-null   float64
#  15  sensor10  4070 non-null   float64
#  16  sensor11  4070 non-null   float64
#  17  sensor12  4070 non-null   float64
#  18  sensor13  4070 non-null   float64
#  19  sensor14  4070 non-null   float64
#  20  sensor15  4070 non-null   float64
#  21  sensor16  4070 non-null   int64
#  22  sensor17  4070 non-null   int64
#  23  sensor18  4070 non-null   float64
#  24  sensor19  4070 non-null   float64
#  25  sensor20  4070 non-null   float64
#  26  sensor21  0 non-null      float64
#  27  sensor22  0 non-null      float64
#  28  sensor23  0 non-null      float64
#  29  sensor24  0 non-null      float64
#  30  sensor25  0 non-null      float64
#  31  rul       4070 non-null   float64
# dtypes: float64(28), int64(4)
# memory usage: 1.0 MB

# %% [markdown]
# # Autokeras

# %%
def fit(df_feature: pd.DataFrame, df_target: pd.DataFrame) -> StructuredDataRegressor:
    """モデルの探索."""
    max_trials = 3 if MODE_DEBUG else 100
    epochs = 10 if MODE_DEBUG else 100
    early_stopping = tkcallbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-4,
        patience=10,
    )

    regressor = StructuredDataRegressor(
        overwrite=True,
        max_trials=max_trials,
        loss="mean_squared_error",
        metrics="mean_squared_error",
        objective="val_loss",
        seed=42,
    )
    regressor.fit(
        df_feature.to_numpy(),
        df_target.to_numpy(),
        epochs=epochs,
        validation_split=0.2,
        callbacks=[early_stopping],
    )

    return regressor


REGRESSOR = fit(DF_TRAIN[COLUMNS_VALID], DF_TRAIN[COLUMNS_TARGET])
# Out:
# Trial 50 Complete [00h 00m 51s]
# val_loss: 5739.16162109375
#
# Best val_loss So Far: 2796.951904296875
# Total elapsed time: 01h 31m 34s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 518/518 [==============================] - 2s 3ms/step - loss: 11978.5985 - mean_squared_error: 11978.5985
# Epoch 2/100
# 518/518 [==============================] - 2s 3ms/step - loss: 2004.4270 - mean_squared_error: 2004.4270
# Epoch 3/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1895.7044 - mean_squared_error: 1895.7044
# Epoch 4/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1843.1040 - mean_squared_error: 1843.1040
# Epoch 5/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1806.0239 - mean_squared_error: 1806.0239
# Epoch 6/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1775.3394 - mean_squared_error: 1775.3394
# Epoch 7/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1748.8373 - mean_squared_error: 1748.8373
# Epoch 8/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1724.8451 - mean_squared_error: 1724.8451
# Epoch 9/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1702.5770 - mean_squared_error: 1702.5770
# Epoch 10/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1680.9821 - mean_squared_error: 1680.9821
# Epoch 11/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1660.3160 - mean_squared_error: 1660.3160
# Epoch 12/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1640.8423 - mean_squared_error: 1640.8423
# Epoch 13/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1624.0962 - mean_squared_error: 1624.0962
# Epoch 14/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1609.4675 - mean_squared_error: 1609.4675
# Epoch 15/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1597.3821 - mean_squared_error: 1597.3821
# Epoch 16/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1588.4813 - mean_squared_error: 1588.4813
# Epoch 17/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1582.2056 - mean_squared_error: 1582.2056
# Epoch 18/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1577.5583 - mean_squared_error: 1577.5583
# Epoch 19/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1574.1108 - mean_squared_error: 1574.1108
# Epoch 20/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1571.3079 - mean_squared_error: 1571.3079
# Epoch 21/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1568.8637 - mean_squared_error: 1568.8637
# Epoch 22/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1566.9957 - mean_squared_error: 1566.9957
# Epoch 23/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1565.1885 - mean_squared_error: 1565.1885
# Epoch 24/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1563.4897 - mean_squared_error: 1563.4897
# Epoch 25/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1562.1423 - mean_squared_error: 1562.1423
# Epoch 26/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1560.8212 - mean_squared_error: 1560.8212
# Epoch 27/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1559.6523 - mean_squared_error: 1559.6523
# Epoch 28/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1558.6368 - mean_squared_error: 1558.6368
# Epoch 29/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1557.5333 - mean_squared_error: 1557.5333
# Epoch 30/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1556.4457 - mean_squared_error: 1556.4457
# Epoch 31/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1555.4484 - mean_squared_error: 1555.4484
# Epoch 32/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1554.6437 - mean_squared_error: 1554.6437
# Epoch 33/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1553.6934 - mean_squared_error: 1553.6934
# Epoch 34/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1552.7528 - mean_squared_error: 1552.7528
# Epoch 35/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1551.5674 - mean_squared_error: 1551.5674
# Epoch 36/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1550.4704 - mean_squared_error: 1550.4704
# Epoch 37/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1549.5151 - mean_squared_error: 1549.5151
# Epoch 38/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1548.7196 - mean_squared_error: 1548.7196
# Epoch 39/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1547.9556 - mean_squared_error: 1547.9556
# Epoch 40/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1547.1586 - mean_squared_error: 1547.1586
# Epoch 41/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1546.2412 - mean_squared_error: 1546.2412
# Epoch 42/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1545.5547 - mean_squared_error: 1545.5547
# Epoch 43/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1544.8136 - mean_squared_error: 1544.8136
# Epoch 44/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1544.1404 - mean_squared_error: 1544.1404
# Epoch 45/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1543.5399 - mean_squared_error: 1543.5399
# Epoch 46/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1542.7274 - mean_squared_error: 1542.7274
# Epoch 47/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1541.9726 - mean_squared_error: 1541.9726
# Epoch 48/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1541.1721 - mean_squared_error: 1541.1721
# Epoch 49/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1540.5983 - mean_squared_error: 1540.5983
# Epoch 50/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1539.7097 - mean_squared_error: 1539.7097
# Epoch 51/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1539.0890 - mean_squared_error: 1539.0890
# Epoch 52/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1538.4005 - mean_squared_error: 1538.4005
# Epoch 53/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1537.8121 - mean_squared_error: 1537.8121
# Epoch 54/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1537.1990 - mean_squared_error: 1537.1990
# Epoch 55/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1536.5990 - mean_squared_error: 1536.5990
# Epoch 56/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1535.8948 - mean_squared_error: 1535.8948
# Epoch 57/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1535.3950 - mean_squared_error: 1535.3950
# Epoch 58/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1534.8733 - mean_squared_error: 1534.8733
# Epoch 59/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1534.2399 - mean_squared_error: 1534.2399
# Epoch 60/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1533.5820 - mean_squared_error: 1533.5820
# Epoch 61/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1532.8321 - mean_squared_error: 1532.8321
# Epoch 62/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1532.0625 - mean_squared_error: 1532.0625
# Epoch 63/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1531.5469 - mean_squared_error: 1531.5469
# Epoch 64/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1530.8746 - mean_squared_error: 1530.8746
# Epoch 65/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1530.0880 - mean_squared_error: 1530.0880
# Epoch 66/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1529.5391 - mean_squared_error: 1529.5391
# Epoch 67/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1528.9244 - mean_squared_error: 1528.9244
# Epoch 68/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1528.2568 - mean_squared_error: 1528.2568
# Epoch 69/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1527.8402 - mean_squared_error: 1527.8402
# Epoch 70/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1527.2507 - mean_squared_error: 1527.2507
# Epoch 71/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1526.9636 - mean_squared_error: 1526.9636
# Epoch 72/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1526.2594 - mean_squared_error: 1526.2594
# Epoch 73/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1525.7476 - mean_squared_error: 1525.7476
# Epoch 74/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1525.1694 - mean_squared_error: 1525.1694
# Epoch 75/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1524.8676 - mean_squared_error: 1524.8676
# Epoch 76/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1524.4920 - mean_squared_error: 1524.4920
# Epoch 77/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1524.0162 - mean_squared_error: 1524.0162
# Epoch 78/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1523.6810 - mean_squared_error: 1523.6810
# Epoch 79/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1523.2725 - mean_squared_error: 1523.2725
# Epoch 80/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1522.7178 - mean_squared_error: 1522.7178
# Epoch 81/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1522.4164 - mean_squared_error: 1522.4164
# Epoch 82/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1521.9484 - mean_squared_error: 1521.9484
# Epoch 83/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1521.5886 - mean_squared_error: 1521.5886
# Epoch 84/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1521.0806 - mean_squared_error: 1521.0806
# Epoch 85/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1520.8893 - mean_squared_error: 1520.8893
# Epoch 86/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1520.5004 - mean_squared_error: 1520.5004
# Epoch 87/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1520.0956 - mean_squared_error: 1520.0956
# Epoch 88/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1519.7930 - mean_squared_error: 1519.7930
# Epoch 89/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1519.5356 - mean_squared_error: 1519.5356
# Epoch 90/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1519.1994 - mean_squared_error: 1519.1994
# Epoch 91/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1519.1395 - mean_squared_error: 1519.1395
# Epoch 92/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1518.7358 - mean_squared_error: 1518.7358
# Epoch 93/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1518.3675 - mean_squared_error: 1518.3675
# Epoch 94/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1517.7685 - mean_squared_error: 1517.7685
# Epoch 95/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1517.5016 - mean_squared_error: 1517.5016
# Epoch 96/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1517.1488 - mean_squared_error: 1517.1488
# Epoch 97/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1516.9979 - mean_squared_error: 1516.9979
# Epoch 98/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1516.6260 - mean_squared_error: 1516.6260
# Epoch 99/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1516.4119 - mean_squared_error: 1516.4119
# Epoch 100/100
# 518/518 [==============================] - 2s 3ms/step - loss: 1516.0825 - mean_squared_error: 1516.0825
# INFO:tensorflow:Assets written to: ./structured_data_regressor/best_model/assets
# INFO:tensorflow:Assets written to: ./structured_data_regressor/best_model/assets

# %%
def export_model(regressor: StructuredDataRegressor, output: pathlib.Path) -> None:
    """モデルをファイルとして保存."""
    model = regressor.export_model()
    model.save(str(output), save_format="tf")

    # test
    loaded_model = tkmodels.load_model(str(output), custom_objects=ak.CUSTOM_OBJECTS)


export_model(REGRESSOR, pathlib.Path("model_autokeras"))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0d7cab90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0d7cab90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab1811bcb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab1811bcb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab182bee60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab182bee60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab18249050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab18249050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab1811b440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab1811b440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0d7cadd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0d7cadd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab182d3050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab182d3050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:tensorflow:Assets written to: model_autokeras/assets
# INFO:tensorflow:Assets written to: model_autokeras/assets
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbfd200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbfd200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb83a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb83a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb838c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb838c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbf9b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbf9b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb844d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb844d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb90950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb90950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbb10e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbb10e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cba5680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cba5680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb91440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cb91440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbfd050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbfd050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbbd050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cbbd050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# ## Results

# %%
def predict(
    regressor: StructuredDataRegressor,
    df_info: pd.DataFrame,
    df_feature: pd.DataFrame,
    df_target: pd.DataFrame,
    units: List[int],
) -> None:
    """予測結果を可視化する."""
    results = regressor.predict(df_feature.to_numpy())
    df_results = df_info.copy()
    df_results["rul"] = df_target.to_numpy().ravel()
    df_results["pred"] = results

    for unit in units:
        df_target = df_results[df_results["unit"] == unit]
        fig, axes = plt.subplots(1, 1, figsize=(9, 4), tight_layout=True)
        ax = axes
        ax.plot(df_target["time"], df_target["rul"], label="rul")
        ax.plot(df_target["time"], df_target["pred"], label="pred")
        ax.set_title(f"unit{unit:02}")
        plt.show()
        plt.close()
        fig.clf()

# %%
predict(
    REGRESSOR,
    DF_VALID[["unit", "time"]],
    DF_VALID[COLUMNS_VALID],
    DF_VALID[COLUMNS_TARGET],
    DF_VALID["unit"].unique()[:3],
)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf6320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf6320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cadcb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cadcb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caea0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caea0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf1440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf1440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf69e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf69e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf6f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf6f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf1830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0caf1830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cae7cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cae7cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cae0290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0cae0290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0ca97b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0ca97b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0ca973b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function recreate_function.<locals>.restored_function_body at 0x7fab0ca973b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
