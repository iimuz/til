# %% [markdown]
# # Chapter 1

# %%
library("LearnBayes")

# %% [markdown]
# ## Chapter 1.2.2

# %%
# load student data
data(studentdata)

# view student data
studentdata[1, ]

# view parameter name
attach(studentdata)
# Out:
#   Student Height Gender Shoes Number Dvds ToSleep WakeUp Haircut Job Drink
# 1 1       67     female 10    5      10   -2.5    5.5    60      30  water

# %% [markdown]
# ## Chapter 1.2.3

# %%
# 集計データ
table(Drink)
# Out:
# Drink
#  milk   pop water
#   113   178   355

# %%
# グラフ表示
barplot(table(Drink), xlab="Drink", ylab="Count")
# Out:
# plot without title

# %%
# 変数の統計量を求める
hours.of.sleep <- WakeUp - ToSleep
summary(hours.of.sleep)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   2.500   6.500   7.500   7.385   8.500  12.500       4

# %%
# ヒストグラムの作成
hist(hours.of.sleep, main="")
# Out:
# Plot with title “”

# %% [markdown]
# ## 1.2.4

# %%
# Gender 別に箱ひげ図をプロットする
boxplot(hours.of.sleep ~ Gender, ylab="Hours of Sleep")
# Out:
# plot without title

# %%
# 男女それぞれの散髪代を調べる
female.Haircut <- Haircut[Gender == "female"]
male.Haircut <- Haircut[Gender == "male"]

print("Female haircut")
summary(female.Haircut)

print("Male haircut")
summary(male.Haircut)
# Out:
# [1] "Female haircut"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.00   15.00   25.00   34.08   45.00  180.00      19
# [1] "Male haircut"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.00    0.00   12.00   10.54   15.00   75.00       1

# %% [markdown]
# ## 1.2.5

# %% [markdown]
# `jitter` 関数によりノイズを付与することで、グラフ上で重なってしまうデータを見やすくすることができる。

# %%
plot(jitter(ToSleep), jitter(hours.of.sleep))
# Out:
# plot without title

# %% [markdown]
# `lm()` 関数を利用することで最小二乗法による直線の回帰が実行できる。

# %%
fit <- lm(hours.of.sleep ~ ToSleep)
fit
# Out:
# Call:
# lm(formula = hours.of.sleep ~ ToSleep)
#
# Coefficients:
# (Intercept)      ToSleep
#      7.9628      -0.5753

# %% [markdown]
# 最小二乗法による直線は、 `abline()` 関数により散布図上に加えることができる。

# %%
plot(jitter(ToSleep), jitter(hours.of.sleep))
abline(fit)
# Out:
# plot without title

# %% [markdown]
# ## 1.3.2

# %% [markdown]
# `rnorm()` 関数を利用することで、任意の正規分布 $N(\mu, \sigma)$ の分布からの標本をシミュレーションすることができる。

# %%
x <- rnorm(10, mean=50, sd=10)
y <- rnorm(10, mean=50, sd=10)

# %% [markdown]
# t 統計量の計算

# %%
tstatistic <- function(x, y) {
    m <- length(x)
    n <- length(y)

    sp <- sqrt(((m - 1) * sd(x) ^ 2 + (n - 1) * sd(y) ^ 2) / (m + n - 2))
    t.stat <- (mean(x) - mean(y)) / (sp * sqrt(1 / m + 1 / n))
    
    return(t.stat)
}

# %%
data.x <- c(1, 4, 3, 6, 5)
data.y <- c(5, 4, 7, 6, 10)
tstatistic(data.x, data.y)
# Out:
# [1] -1.937926
